# %%
import pandas as pd
import re

parts = pd.read_csv("../data/cleaned/part_clean.csv")

parts.head()
# Out:
#    Unnamed: 0  \
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
#
#                                                                   part_raw  \
# 0                            butelka filtrująca dafi solid 0,7 l szafirowa
# 1                                                       filtr węglowy (x1)
# 2   rurka na filtr do butelki filtrującej dafi solid 0,7 l szafirowym (x1)
# 3  zestaw 3 filtry do butelki filtrującej dafi soft i solid szafirowy (x1)
# 4                                                          zestaw 2 filtry
#
#    qty                                                          part_clean
# 0    1                       butelka filtrująca dafi solid 0,7 l szafirowa
# 1    1                                                       filtr węglowy
# 2    1   rurka na filtr do butelki filtrującej dafi solid 0,7 l szafirowym
# 3    1  zestaw 3 filtry do butelki filtrującej dafi soft i solid szafirowy
# 4    1                                                     zestaw 2 filtry

# %%
pd.set_option("display.max_colwidth", None)

# %%
'''MAP'''

RULES = {
    "bottle": [r"\bbutelka\b"],
    "pitcher": [r"\bdzbanek\b"],
    "accessory": [r"\brurka\b", r"\bnakretka\b", r"\bnakrętka\b"],
    "filter_set": [r"\bzestaw\b.*\bfiltr", r"\bzestaw\b.*\bwklad", r"\bzestaw\b.*\bwkład"],
    "filter": [r"\bfiltr\b", r"\bwklad\b", r"\bwkład\b"],
}

RULES["filter"] = [r"\bfiltr\b", r"\bfiltry\b", r"\bwklad\b", r"\bwkład\b", r"\bwklady\b", r"\bwkłady\b"]

# %%
import re

CATEGORY_ORDER = ["bottle", "pitcher", "accessory", "filter_set", "filter"]

def classify(text):
    for cat in CATEGORY_ORDER:
        patterns = RULES[cat]
        if any(re.search(p, text) for p in patterns):
            return cat
    return "other"

# %%
parts["category"] = parts["part_clean"].apply(classify)

# %%
parts["category"].value_counts()
# Out:
# category
# filter        11504
# bottle         8749
# filter_set     7587
# other          6646
# pitcher        4959
# accessory       984
# Name: count, dtype: int64

# %%
def extract_pack_size(text):
    # looks for "3 filtry", "8 filtrów", "2 wkłady", etc.
    m = re.findall(r"\b(\d+)\b\s*(filtr|filtry|filtrow|filtrów|wklad|wkład|wklady|wkłady)", text)
    if m:
        return sum(int(n) for n, _ in m)

    # fallback: "zestaw 3 ..." (if sometimes missing 'filtry' right after)
    m2 = re.search(r"\bzestaw\b\s*(\d+)\b", text)
    if m2:
        return int(m2.group(1))

    return np.nan

# %%
parts["pack_size"] = parts["part_clean"].apply(extract_pack_size)

parts["filter_units"] = 0

mask_set = parts["category"].eq("filter_set")
parts.loc[mask_set, "filter_units"] = parts.loc[mask_set, "pack_size"].fillna(1) * parts.loc[mask_set, "qty"]

mask_filter = parts["category"].eq("filter")
parts.loc[mask_filter, "filter_units"] = parts.loc[mask_filter, "pack_size"].fillna(1) * parts.loc[mask_filter, "qty"]

# %%
import numpy as np
import re

def has_any(text, patterns):
    return any(re.search(p, text) for p in patterns)

parts["is_wklad"] = parts["part_clean"].apply(lambda s: has_any(s, [r"\bwkład\b", r"\bwkłady\b", r"\bwklady\b", r"\bwklad\b"]))
parts["is_filtr"] = parts["part_clean"].apply(lambda s: has_any(s, [r"\bfiltr\b", r"\bfiltry\b", r"\bfiltrów\b", r"\bfiltrow\b"]))

# Identify destination when it is explicitly written
parts["dest"] = np.where(parts["part_clean"].str.contains(r"\bdo dzban", regex=True), "pitcher",
                 np.where(parts["part_clean"].str.contains(r"\bdo butelk", regex=True), "bottle", "unknown"))

# Pack size (reuse your function)
parts["pack_size"] = parts["part_clean"].apply(extract_pack_size)

# Base units from text: if number exists use it, otherwise 1
parts["units"] = parts["pack_size"].fillna(1) * parts["qty"]

# %%
parts["bottle_filter_units"] = 0
parts["pitcher_insert_units"] = 0

is_consumable = parts["category"].isin(["filter", "filter_set"])

# wkład => pitcher inserts (only if consumable line)
mask_wklad = is_consumable & parts["is_wklad"]
parts.loc[mask_wklad, "pitcher_insert_units"] = parts.loc[mask_wklad, "units"]

# filtr => bottle filters (only if consumable line AND not wkład)
mask_filtr = is_consumable & parts["is_filtr"] & (~parts["is_wklad"])
parts.loc[mask_filtr, "bottle_filter_units"] = parts.loc[mask_filtr, "units"]

# %%
parts["bottle_included_filter_units"] = 0
parts.loc[parts["category"].eq("bottle"), "bottle_included_filter_units"] = parts.loc[parts["category"].eq("bottle"), "qty"]  # 1 per bottle

# %%
parts.loc[
    (parts["is_filtr"] | parts["is_wklad"] | parts["category"].isin(["bottle","pitcher"])),
    ["part_clean","category","qty","dest","bottle_filter_units","pitcher_insert_units","bottle_included_filter_units"]
].head(40)
# Out:
#                                                              part_clean  \
# 0                         butelka filtrująca dafi solid 0,7 l szafirowa
# 1                                                         filtr węglowy
# 2     rurka na filtr do butelki filtrującej dafi solid 0,7 l szafirowym
# 3    zestaw 3 filtry do butelki filtrującej dafi soft i solid szafirowy
# 4                                                       zestaw 2 filtry
# 6    zestaw 3 filtry do butelki filtrującej dafi soft i solid cytrynowy
# 7                            butelka filtrująca dafi soft 0,3 l stalowa
# 8                                                         filtr węglowy
# 9                           butelka filtrująca dafi soft 0,5 l jagodowa
# 10                                                        filtr węglowy
# 11    zestaw 3 filtry do butelki filtrującej dafi soft i solid jeansowy
# 12                                    zestaw filtrów unimax: 2 standard
# 14                  dzbanek filtrujący dafi luna stalowy 3,3 l manualny
# 15                                                     2 wkłady classic
# 16            dzbanek filtrujący dafi astra makowy 3 l led wkład unimax
# 17    zestaw 3 filtry do butelki filtrującej dafi soft i solid jagodowy
# 18            dzbanek filtrujący dafi mila stalowy 3 l led wkład unimax
# 19           zestaw 8 filtrów do dzbanka filtrującego dafi wkład unimax
# 20                       butelka filtrująca dafi solid 0,7 l flamingowa
# 21                                                        filtr węglowy
# 22  zestaw 3 filtry do butelki filtrującej dafi soft i solid flamingowy
# 23                zestaw szklany dzbanek dafi crystal led 2 l grafitowy
# 25                    zestaw szklany dzbanek dafi crystal led 2 l biały
# 27                          butelka filtrująca dafi solid 0,7 l stalowa
# 28                                                        filtr węglowy
# 29                         butelka filtrująca dafi solid 0,7 l jeansowa
# 30                                                        filtr węglowy
# 31                zestaw szklany dzbanek dafi crystal led 2 l grafitowy
# 33    rurka na filtr do butelki filtrującej dafi solid 0,5 l flamingowa
# 34       zestaw 3 filtry do butelki filtrującej dafi soft i solid biały
# 35                        butelka filtrująca dafi solid 0,7 l cytrynowa
# 36                                                        filtr węglowy
# 37                       butelka filtrująca dafi solid 0,7 l flamingowa
# 38                                                        filtr węglowy
# 39                            butelka filtrująca dafi soft 0,5 l czarna
# 40                                                        filtr węglowy
# 41   zestaw 3 filtry do butelki filtrującej dafi soft i solid cytrynowy
# 42           zestaw 8 filtrów do dzbanka filtrującego dafi wkład unimax
# 43      rurka na filtr do butelki filtrującej dafi solid 0,5 l jeansowa
# 44                  zestaw szklany dzbanek dafi crystal led 2 l miętowy
#
#       category  qty     dest  bottle_filter_units  pitcher_insert_units  \
# 0       bottle    1  unknown                    0                     0
# 1       filter    1  unknown                    1                     0
# 2    accessory    1   bottle                    0                     0
# 3   filter_set    1   bottle                    3                     0
# 4   filter_set    1  unknown                    2                     0
# 6   filter_set    1   bottle                    3                     0
# 7       bottle    1  unknown                    0                     0
# 8       filter    1  unknown                    1                     0
# 9       bottle    1  unknown                    0                     0
# 10      filter    1  unknown                    1                     0
# 11  filter_set    1   bottle                    3                     0
# 12  filter_set    1  unknown                    1                     0
# 14     pitcher    1  unknown                    0                     0
# 15      filter    1  unknown                    0                     2
# 16     pitcher    1  unknown                    0                     0
# 17  filter_set    1   bottle                    3                     0
# 18     pitcher    1  unknown                    0                     0
# 19  filter_set    1  pitcher                    0                     8
# 20      bottle    1  unknown                    0                     0
# 21      filter    1  unknown                    1                     0
# 22  filter_set    1   bottle                    3                     0
# 23     pitcher    1  unknown                    0                     0
# 25     pitcher    1  unknown                    0                     0
# 27      bottle    1  unknown                    0                     0
# 28      filter    1  unknown                    1                     0
# 29      bottle    1  unknown                    0                     0
# 30      filter    1  unknown                    1                     0
# 31     pitcher    1  unknown                    0                     0
# 33   accessory    2   bottle                    0                     0
# 34  filter_set    1   bottle                    3                     0
# 35      bottle    1  unknown                    0                     0
# 36      filter    1  unknown                    1                     0
# 37      bottle    1  unknown                    0                     0
# 38      filter    1  unknown                    1                     0
# 39      bottle    1  unknown                    0                     0
# 40      filter    1  unknown                    1                     0
# 41  filter_set    1   bottle                    3                     0
# 42  filter_set    1  pitcher                    0                     8
# 43   accessory    2   bottle                    0                     0
# 44     pitcher    1  unknown                    0                     0
#
#     bottle_included_filter_units
# 0                              1
# 1                              0
# 2                              0
# 3                              0
# 4                              0
# 6                              0
# 7                              1
# 8                              0
# 9                              1
# 10                             0
# 11                             0
# 12                             0
# 14                             0
# 15                             0
# 16                             0
# 17                             0
# 18                             0
# 19                             0
# 20                             1
# 21                             0
# 22                             0
# 23                             0
# 25                             0
# 27                             1
# 28                             0
# 29                             1
# 30                             0
# 31                             0
# 33                             0
# 34                             0
# 35                             1
# 36                             0
# 37                             1
# 38                             0
# 39                             1
# 40                             0
# 41                             0
# 42                             0
# 43                             0
# 44                             0

# %%
parts["bottle_units"] = 0
parts["pitcher_units"] = 0
parts["accessory_units"] = 0
parts["other_units"] = 0

parts.loc[parts["category"].eq("bottle"), "bottle_units"] = parts.loc[parts["category"].eq("bottle"), "qty"]
parts.loc[parts["category"].eq("pitcher"), "pitcher_units"] = parts.loc[parts["category"].eq("pitcher"), "qty"]
parts.loc[parts["category"].eq("accessory"), "accessory_units"] = parts.loc[parts["category"].eq("accessory"), "qty"]
parts.loc[parts["category"].eq("other"), "other_units"] = parts.loc[parts["category"].eq("other"), "qty"]

# %%
parts.to_csv("../data/cleaned/decoded.csv")

# %%
# columns that identify an order (adjust if your order id column name differs)
ORDER_COLS = ["kolejności", "Anon", "Data zakupu"]

parts = (
    df[ORDER_COLS + ["product_parts"]]
      .explode("product_parts")
      .rename(columns={"product_parts": "part_raw"})
      .copy()
)

parts["part_raw"] = parts["part_raw"].fillna("")
parts["part_clean"] = parts["part_raw"].apply(strip_qty)
parts["qty"] = parts["part_raw"].apply(get_qty)

# re-classify
parts["category"] = parts["part_clean"].apply(classify)

# recompute pack_size + units using your improved extractor
parts["pack_size"] = parts["part_clean"].apply(extract_pack_size)
parts["units"] = parts["pack_size"].fillna(1) * parts["qty"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 5
#       1 # columns that identify an order (adjust if your order id column name differs)
#       2 ORDER_COLS = ["kolejności", "Anon", "Data zakupu"]
#       4 parts = (
# ----> 5     df[ORDER_COLS + ["product_parts"]]
#       6       .explode("product_parts")
#       7       .rename(columns={"product_parts": "part_raw"})
#       8       .copy()
#       9 )
#      11 parts["part_raw"] = parts["part_raw"].fillna("")
#      12 parts["part_clean"] = parts["part_raw"].apply(strip_qty)
#
# NameError: name 'df' is not defined
