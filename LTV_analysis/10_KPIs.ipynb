# %%
from pathlib import Path
import pandas as pd
import numpy as np

DATA_DIR = Path("../data/interim")

# %%
pd.read_parquet(DATA_DIR / "transition_1_to_2.parquet")
df_k = pd.read_parquet(DATA_DIR / "cust_day_group.parquet")

# %%
T12 = pd.read_parquet(DATA_DIR / "transition_1_to_2.parquet")
T23 = pd.read_parquet(DATA_DIR / "transition_2_to_3.parquet")
T34 = pd.read_parquet(DATA_DIR / "transition_3_to_4.parquet")

# %%
top_share_12 = T12.max(axis=1)
top_share_12.sort_values(ascending=False).head(10)
# Out:
# entry_group
# 24_Filtry przepływowe - wkłady      0.769780
# 32_nabój CO2 - wymiana              0.639483
# 26_podgrzewacze przepływowe         0.613861
# 27_Proskin - urządzenia i filtry    0.597847
# 19_Flow Comfort D1 trójdrożna       0.592121
# 21_wkład D1 do Flow Comfort         0.561612
# 23_Filtry przepływowe - obudowy     0.560467
# 16_filtry do dzbanków AGD+          0.535449
# 22_wkład DC10 do Flow Comfort       0.518315
# 17_Flow Comfort D1 jednodrożna      0.464698
# dtype: float64

# %%
# keep only purchase rows
df_k = df_k[df_k["is_purchase"] == True].copy()

df_k = df_k.dropna(subset=["date"])


# convert date column to datetime
df_k["date"] = pd.to_datetime(df_k["date"], dayfirst=True, errors="coerce")

# parse date properly
df_k["date"] = pd.to_datetime(df_k["date"], dayfirst=True)

# assign purchase number per customer
df_k["purchase_k"] = (
    df_k
    .sort_values(["anon", "date"])
    .groupby("anon")["date"]
    .rank(method="dense")
    .astype(int)
)

# %%
entry_support = (
    df_k[df_k["purchase_k"] == 1]
    [["anon", "MATRIX GRUPA PRODUKTOWA"]]
    .drop_duplicates()
    .groupby("MATRIX GRUPA PRODUKTOWA")["anon"]
    .nunique()
    .rename("n_customers")
    .sort_values(ascending=False)
)

entry_support.head(10)
# Out:
# MATRIX GRUPA PRODUKTOWA
# 06_filtry do butelek Soft i Solid    110942
# 03_butelki filtrujące SOLID           91701
# 13_filtry do dzbanków standard        68321
# 08_dzbanki filtrujące manualne        56071
# 10_dzbanki filtrujące Crystal         41610
# 02_butelki filtrujące SOFT            30626
# 07_akcesoria do Soft/Solid            28331
# 38_inne                               13482
# 16_filtry do dzbanków AGD+            12608
# 09_dzbanki filtrujące LED             11763
# Name: n_customers, dtype: int64

# %%
top_share_12 = T12.max(axis=1).rename("top_share")

kpi_12 = (
    pd.concat([top_share_12, entry_support], axis=1)
    .dropna()
    .sort_values("n_customers", ascending=False)
)

kpi_12.head(10)
# Out:
#                                    top_share  n_customers
# 06_filtry do butelek Soft i Solid   0.417760       110942
# 03_butelki filtrujące SOLID         0.364796        91701
# 13_filtry do dzbanków standard      0.379161        68321
# 08_dzbanki filtrujące manualne      0.363807        56071
# 10_dzbanki filtrujące Crystal       0.317696        41610
# 02_butelki filtrujące SOFT          0.313916        30626
# 07_akcesoria do Soft/Solid          0.312100        28331
# 38_inne                             0.245131        13482
# 16_filtry do dzbanków AGD+          0.535449        12608
# 09_dzbanki filtrujące LED           0.225808        11763

# %%
support_threshold = entry_support.median()
top_share_threshold = top_share_12.median()

support_threshold, top_share_threshold
# Out:
# (2319.0, 0.31769608634908975)

# %%
kpi_12["gateway_candidate"] = (
    (kpi_12["n_customers"] >= support_threshold) &
    (kpi_12["top_share"] >= top_share_threshold)
)

# %%
kpi_12.sort_values(
    ["gateway_candidate", "n_customers", "top_share"],
    ascending=[False, False, False]
).head(15)
# Out:
#                                    top_share  n_customers  gateway_candidate
# 06_filtry do butelek Soft i Solid   0.417760       110942               True
# 03_butelki filtrujące SOLID         0.364796        91701               True
# 13_filtry do dzbanków standard      0.379161        68321               True
# 08_dzbanki filtrujące manualne      0.363807        56071               True
# 10_dzbanki filtrujące Crystal       0.317696        41610               True
# 16_filtry do dzbanków AGD+          0.535449        12608               True
# 35_pojemniki SeeYou                 0.435802         7163               True
# 24_Filtry przepływowe - wkłady      0.769780         7150               True
# 21_wkład D1 do Flow Comfort         0.561612         2319               True
# 02_butelki filtrujące SOFT          0.313916        30626              False
# 07_akcesoria do Soft/Solid          0.312100        28331              False
# 38_inne                             0.245131        13482              False
# 09_dzbanki filtrujące LED           0.225808        11763              False
# 05_butelki i kubki termiczne        0.216440        11697              False
# 01_bidony                           0.250895         9349              False

# %%
same_category_12 = pd.Series(
    np.diag(T12.loc[T12.index, T12.index].values),
    index=T12.index,
    name="same_category"
)

# %%
kpi_12 = kpi_12.join(same_category_12)
kpi_12.head(10)
# Out:
#                                    top_share  n_customers  gateway_candidate  \
# 06_filtry do butelek Soft i Solid   0.417760       110942               True
# 03_butelki filtrujące SOLID         0.364796        91701               True
# 13_filtry do dzbanków standard      0.379161        68321               True
# 08_dzbanki filtrujące manualne      0.363807        56071               True
# 10_dzbanki filtrujące Crystal       0.317696        41610               True
# 02_butelki filtrujące SOFT          0.313916        30626              False
# 07_akcesoria do Soft/Solid          0.312100        28331              False
# 38_inne                             0.245131        13482              False
# 16_filtry do dzbanków AGD+          0.535449        12608               True
# 09_dzbanki filtrujące LED           0.225808        11763              False
#
#                                    same_category
# 06_filtry do butelek Soft i Solid       0.417760
# 03_butelki filtrujące SOLID             0.364796
# 13_filtry do dzbanków standard          0.379161
# 08_dzbanki filtrujące manualne          0.363807
# 10_dzbanki filtrujące Crystal           0.248636
# 02_butelki filtrujące SOFT              0.313916
# 07_akcesoria do Soft/Solid              0.278569
# 38_inne                                 0.032608
# 16_filtry do dzbanków AGD+              0.535449
# 09_dzbanki filtrujące LED               0.225808

# %%
same_threshold = kpi_12["same_category"].median()

kpi_12["gateway_type"] = np.where(
    kpi_12["gateway_candidate"] & (kpi_12["same_category"] < same_threshold),
    "gateway_push",
    np.where(
        kpi_12["gateway_candidate"],
        "gateway_repeat",
        "non_gateway"
    )
)

kpi_12.sort_values(
    ["gateway_type", "n_customers"],
    ascending=[True, False]
)
# Out:
#                                        top_share  n_customers  \
# 06_filtry do butelek Soft i Solid       0.417760       110942
# 03_butelki filtrujące SOLID             0.364796        91701
# 13_filtry do dzbanków standard          0.379161        68321
# 08_dzbanki filtrujące manualne          0.363807        56071
# 10_dzbanki filtrujące Crystal           0.317696        41610
# 16_filtry do dzbanków AGD+              0.535449        12608
# 35_pojemniki SeeYou                     0.435802         7163
# 24_Filtry przepływowe - wkłady          0.769780         7150
# 21_wkład D1 do Flow Comfort             0.561612         2319
# 02_butelki filtrujące SOFT              0.313916        30626
# 07_akcesoria do Soft/Solid              0.312100        28331
# 38_inne                                 0.245131        13482
# 09_dzbanki filtrujące LED               0.225808        11763
# 05_butelki i kubki termiczne            0.216440        11697
# 01_bidony                               0.250895         9349
# 14_filtry do dzbanków Mg+               0.304843         9189
# 30_saturator PushAir                    0.185414         8157
# 34_suplementy PushAir                   0.154848         7494
# 33_butelki do saturatora PushAir        0.229380         3533
# 25_Filtry przepływowe - akcesoria       0.392002         2105
# 04_termiczna butelka filtrująca SOLID   0.301545         2015
# 17_Flow Comfort D1 jednodrożna          0.464698         2015
# 32_nabój CO2 - wymiana                  0.639483         1876
# 31_nabój CO2 - zakup                    0.304398         1792
# 26_podgrzewacze przepływowe             0.613861         1558
# 36_akcesoria SeeYou                     0.382249         1383
# 22_wkład DC10 do Flow Comfort           0.518315         1376
# 15_filtry do dzbanków Ph+               0.298923         1250
# 18_Flow Comfort DC10 jednodrożna        0.412696         1188
# 11_czajnik filtrujący                   0.263401         1132
# 23_Filtry przepływowe - obudowy         0.560467         1001
# 19_Flow Comfort D1 trójdrożna           0.592121          753
# 27_Proskin - urządzenia i filtry        0.597847          380
# 28_dzbanki akcesoria                    0.283864          287
# 37_akcesoria PushAir                    0.162416          226
# 20_Flow Comfort DC10 trójdrożna         0.308943           55
# 09_dzbanki PRISMA LED                   0.283019           26
#
#                                        gateway_candidate  same_category  \
# 06_filtry do butelek Soft i Solid                   True       0.417760
# 03_butelki filtrujące SOLID                         True       0.364796
# 13_filtry do dzbanków standard                      True       0.379161
# 08_dzbanki filtrujące manualne                      True       0.363807
# 10_dzbanki filtrujące Crystal                       True       0.248636
# 16_filtry do dzbanków AGD+                          True       0.535449
# 35_pojemniki SeeYou                                 True       0.435802
# 24_Filtry przepływowe - wkłady                      True       0.769780
# 21_wkład D1 do Flow Comfort                         True       0.561612
# 02_butelki filtrujące SOFT                         False       0.313916
# 07_akcesoria do Soft/Solid                         False       0.278569
# 38_inne                                            False       0.032608
# 09_dzbanki filtrujące LED                          False       0.225808
# 05_butelki i kubki termiczne                       False       0.189278
# 01_bidony                                          False       0.250895
# 14_filtry do dzbanków Mg+                          False       0.304843
# 30_saturator PushAir                               False       0.101487
# 34_suplementy PushAir                              False       0.148193
# 33_butelki do saturatora PushAir                   False       0.216785
# 25_Filtry przepływowe - akcesoria                  False       0.170841
# 04_termiczna butelka filtrująca SOLID              False       0.105932
# 17_Flow Comfort D1 jednodrożna                     False       0.111053
# 32_nabój CO2 - wymiana                             False       0.639483
# 31_nabój CO2 - zakup                               False       0.149400
# 26_podgrzewacze przepływowe                        False       0.613861
# 36_akcesoria SeeYou                                False       0.217983
# 22_wkład DC10 do Flow Comfort                      False       0.518315
# 15_filtry do dzbanków Ph+                          False       0.298923
# 18_Flow Comfort DC10 jednodrożna                   False       0.062622
# 11_czajnik filtrujący                              False       0.142479
# 23_Filtry przepływowe - obudowy                    False       0.131775
# 19_Flow Comfort D1 trójdrożna                      False       0.030176
# 27_Proskin - urządzenia i filtry                   False       0.597847
# 28_dzbanki akcesoria                               False       0.005216
# 37_akcesoria PushAir                               False       0.055579
# 20_Flow Comfort DC10 trójdrożna                    False       0.000000
# 09_dzbanki PRISMA LED                              False       0.000000
#
#                                          gateway_type
# 06_filtry do butelek Soft i Solid      gateway_repeat
# 03_butelki filtrujące SOLID            gateway_repeat
# 13_filtry do dzbanków standard         gateway_repeat
# 08_dzbanki filtrujące manualne         gateway_repeat
# 10_dzbanki filtrujące Crystal          gateway_repeat
# 16_filtry do dzbanków AGD+             gateway_repeat
# 35_pojemniki SeeYou                    gateway_repeat
# 24_Filtry przepływowe - wkłady         gateway_repeat
# 21_wkład D1 do Flow Comfort            gateway_repeat
# 02_butelki filtrujące SOFT                non_gateway
# 07_akcesoria do Soft/Solid                non_gateway
# 38_inne                                   non_gateway
# 09_dzbanki filtrujące LED                 non_gateway
# 05_butelki i kubki termiczne              non_gateway
# 01_bidony                                 non_gateway
# 14_filtry do dzbanków Mg+                 non_gateway
# 30_saturator PushAir                      non_gateway
# 34_suplementy PushAir                     non_gateway
# 33_butelki do saturatora PushAir          non_gateway
# 25_Filtry przepływowe - akcesoria         non_gateway
# 04_termiczna butelka filtrująca SOLID     non_gateway
# 17_Flow Comfort D1 jednodrożna            non_gateway
# 32_nabój CO2 - wymiana                    non_gateway
# 31_nabój CO2 - zakup                      non_gateway
# 26_podgrzewacze przepływowe               non_gateway
# 36_akcesoria SeeYou                       non_gateway
# 22_wkład DC10 do Flow Comfort             non_gateway
# 15_filtry do dzbanków Ph+                 non_gateway
# 18_Flow Comfort DC10 jednodrożna          non_gateway
# 11_czajnik filtrujący                     non_gateway
# 23_Filtry przepływowe - obudowy           non_gateway
# 19_Flow Comfort D1 trójdrożna             non_gateway
# 27_Proskin - urządzenia i filtry          non_gateway
# 28_dzbanki akcesoria                      non_gateway
# 37_akcesoria PushAir                      non_gateway
# 20_Flow Comfort DC10 trójdrożna           non_gateway
# 09_dzbanki PRISMA LED                     non_gateway

# %%
kpi_12["cross_category"] = 1 - kpi_12["same_category"]

kpi_12.sort_values(
    ["cross_category", "n_customers"],
    ascending=[False, False]
).tail(15)
# Out:
#                                    top_share  n_customers  gateway_candidate  \
# 15_filtry do dzbanków Ph+           0.298923         1250              False
# 14_filtry do dzbanków Mg+           0.304843         9189              False
# 02_butelki filtrujące SOFT          0.313916        30626              False
# 08_dzbanki filtrujące manualne      0.363807        56071               True
# 03_butelki filtrujące SOLID         0.364796        91701               True
# 13_filtry do dzbanków standard      0.379161        68321               True
# 06_filtry do butelek Soft i Solid   0.417760       110942               True
# 35_pojemniki SeeYou                 0.435802         7163               True
# 22_wkład DC10 do Flow Comfort       0.518315         1376              False
# 16_filtry do dzbanków AGD+          0.535449        12608               True
# 21_wkład D1 do Flow Comfort         0.561612         2319               True
# 27_Proskin - urządzenia i filtry    0.597847          380              False
# 26_podgrzewacze przepływowe         0.613861         1558              False
# 32_nabój CO2 - wymiana              0.639483         1876              False
# 24_Filtry przepływowe - wkłady      0.769780         7150               True
#
#                                    same_category    gateway_type  \
# 15_filtry do dzbanków Ph+               0.298923     non_gateway
# 14_filtry do dzbanków Mg+               0.304843     non_gateway
# 02_butelki filtrujące SOFT              0.313916     non_gateway
# 08_dzbanki filtrujące manualne          0.363807  gateway_repeat
# 03_butelki filtrujące SOLID             0.364796  gateway_repeat
# 13_filtry do dzbanków standard          0.379161  gateway_repeat
# 06_filtry do butelek Soft i Solid       0.417760  gateway_repeat
# 35_pojemniki SeeYou                     0.435802  gateway_repeat
# 22_wkład DC10 do Flow Comfort           0.518315     non_gateway
# 16_filtry do dzbanków AGD+              0.535449  gateway_repeat
# 21_wkład D1 do Flow Comfort             0.561612  gateway_repeat
# 27_Proskin - urządzenia i filtry        0.597847     non_gateway
# 26_podgrzewacze przepływowe             0.613861     non_gateway
# 32_nabój CO2 - wymiana                  0.639483     non_gateway
# 24_Filtry przepływowe - wkłady          0.769780  gateway_repeat
#
#                                    cross_category
# 15_filtry do dzbanków Ph+                0.701077
# 14_filtry do dzbanków Mg+                0.695157
# 02_butelki filtrujące SOFT               0.686084
# 08_dzbanki filtrujące manualne           0.636193
# 03_butelki filtrujące SOLID              0.635204
# 13_filtry do dzbanków standard           0.620839
# 06_filtry do butelek Soft i Solid        0.582240
# 35_pojemniki SeeYou                      0.564198
# 22_wkład DC10 do Flow Comfort            0.481685
# 16_filtry do dzbanków AGD+               0.464551
# 21_wkład D1 do Flow Comfort              0.438388
# 27_Proskin - urządzenia i filtry         0.402153
# 26_podgrzewacze przepływowe              0.386139
# 32_nabój CO2 - wymiana                   0.360517
# 24_Filtry przepływowe - wkłady           0.230220
